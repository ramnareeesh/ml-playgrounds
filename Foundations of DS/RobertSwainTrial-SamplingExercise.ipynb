# %%
import numpy
from numpy import random as rnd
import pandas as pd
import matplotlib.pyplot as plt

# %%
population_dist = [0.26, 0.74]

# %%
rnd.binomial(n=100, p=0.26)
# Out:
# 31

# %%
no_simulations = 1000
for i in range(no_simulations):
    black_chosen = rnd.binomial(100, 0.26, i)

# %%
black_chosen
# Out:
# array([26, 34, 29, 30, 34, 23, 22, 22, 24, 25, 22, 24, 22, 35, 33, 35, 25,
#        19, 20, 18, 28, 29, 25, 28, 22, 21, 24, 26, 30, 17, 37, 35, 27, 20,
#        24, 22, 22, 27, 22, 25, 26, 28, 26, 27, 29, 20, 29, 26, 22, 22, 23,
#        21, 19, 21, 29, 26, 25, 20, 21, 27, 27, 30, 25, 25, 27, 27, 28, 20,
#        24, 26, 22, 18, 28, 29, 28, 28, 25, 28, 32, 25, 18, 29, 32, 29, 26,
#        27, 24, 26, 29, 23, 22, 23, 28, 19, 28, 25, 15, 28, 25, 16, 34, 29,
#        25, 25, 32, 24, 24, 40, 28, 19, 30, 27, 22, 24, 27, 23, 30, 29, 29,
#        21, 20, 28, 33, 21, 33, 33, 30, 28, 27, 23, 26, 25, 23, 23, 24, 31,
#        27, 33, 23, 32, 20, 24, 25, 25, 33, 27, 20, 24, 25, 24, 37, 35, 27,
#        23, 27, 26, 17, 30, 32, 27, 27, 30, 22, 24, 26, 29, 27, 19, 22, 26,
#        22, 28, 25, 27, 31, 20, 20, 26, 29, 23, 22, 27, 26, 21, 31, 36, 19,
#        30, 31, 25, 24, 31, 20, 31, 26, 25, 25, 26, 21, 31, 21, 34, 26, 27,
# ...

# %%
no_blacks = pd.DataFrame(black_chosen, columns=["No of Black Chosen for Jury"])

# %%
no_blacks
# Out:
#      No of Black Chosen for Jury
# 0                             26
# 1                             34
# 2                             29
# 3                             30
# 4                             34
# ..                           ...
# 994                           25
# 995                           25
# 996                           20
# 997                           27
# 998                           29
#
# [999 rows x 1 columns]

# %%
plt.grid(True, linestyle='--', linewidth=0.5)
plt.xlabel(no_blacks.columns[0])
plt.ylabel("Units")
plt.hist(no_blacks)
plt.scatter(8, 0, color= "red")
plt.show()
